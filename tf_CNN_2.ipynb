# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# C:\Users\chenx\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-1-59efcb07063c>:3: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\chenx\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\chenx\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\chenx\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\chenx\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\chenx\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# %%
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

# %%
x = tf.placeholder("float",shape=[None, 784],name="x")    
x_image = tf.reshape(x, [-1, 28, 28, 1])

# %%
y_ = tf.placeholder("float", shape=[None, 10],name="y_")

# %%
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# %%
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# %%
W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# %%
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# %%
W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# %%
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(20000):
        batch = mnist.train.next_batch(50)
        if i%100 == 0:
            train_accuracy = accuracy.eval(feed_dict={x:batch[0], y_: batch[1], keep_prob: 1.0})
        print("step %d, training accuracy %g"%(i, train_accuracy))
        train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})

    print("test accuracy %g"%accuracy.eval(feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
# Out:
# step 0, training accuracy 0.16
# step 1, training accuracy 0.16
# step 2, training accuracy 0.16
# step 3, training accuracy 0.16
# step 4, training accuracy 0.16
# step 5, training accuracy 0.16
# step 6, training accuracy 0.16
# step 7, training accuracy 0.16
# step 8, training accuracy 0.16
# step 9, training accuracy 0.16
# step 10, training accuracy 0.16
# step 11, training accuracy 0.16
# step 12, training accuracy 0.16
# step 13, training accuracy 0.16
# step 14, training accuracy 0.16
# step 15, training accuracy 0.16
# step 16, training accuracy 0.16
# step 17, training accuracy 0.16
# step 18, training accuracy 0.16
# step 19, training accuracy 0.16
# step 20, training accuracy 0.16
# step 21, training accuracy 0.16
# step 22, training accuracy 0.16
# step 23, training accuracy 0.16
# step 24, training accuracy 0.16
# step 25, training accuracy 0.16
# step 26, training accuracy 0.16
# step 27, training accuracy 0.16
# step 28, training accuracy 0.16
# step 29, training accuracy 0.16
# step 30, training accuracy 0.16
# step 31, training accuracy 0.16
# step 32, training accuracy 0.16
# step 33, training accuracy 0.16
# step 34, training accuracy 0.16
# step 35, training accuracy 0.16
# step 36, training accuracy 0.16
# step 37, training accuracy 0.16
# step 38, training accuracy 0.16
# step 39, training accuracy 0.16
# step 40, training accuracy 0.16
# step 41, training accuracy 0.16
# step 42, training accuracy 0.16
# step 43, training accuracy 0.16
# step 44, training accuracy 0.16
# step 45, training accuracy 0.16
# step 46, training accuracy 0.16
# step 47, training accuracy 0.16
# step 48, training accuracy 0.16
# step 49, training accuracy 0.16
# step 50, training accuracy 0.16
# step 51, training accuracy 0.16
# step 52, training accuracy 0.16
# step 53, training accuracy 0.16
# step 54, training accuracy 0.16
# step 55, training accuracy 0.16
# step 56, training accuracy 0.16
# step 57, training accuracy 0.16
# step 58, training accuracy 0.16
# step 59, training accuracy 0.16
# step 60, training accuracy 0.16
# step 61, training accuracy 0.16
# step 62, training accuracy 0.16
# step 63, training accuracy 0.16
# step 64, training accuracy 0.16
# step 65, training accuracy 0.16
# step 66, training accuracy 0.16
# step 67, training accuracy 0.16
# step 68, training accuracy 0.16
# step 69, training accuracy 0.16
# step 70, training accuracy 0.16
# step 71, training accuracy 0.16
# step 72, training accuracy 0.16
# step 73, training accuracy 0.16
# step 74, training accuracy 0.16
# step 75, training accuracy 0.16
# step 76, training accuracy 0.16
# step 77, training accuracy 0.16
# step 78, training accuracy 0.16
# step 79, training accuracy 0.16
# step 80, training accuracy 0.16
# step 81, training accuracy 0.16
# step 82, training accuracy 0.16
# step 83, training accuracy 0.16
# step 84, training accuracy 0.16
# step 85, training accuracy 0.16
# step 86, training accuracy 0.16
# step 87, training accuracy 0.16
# step 88, training accuracy 0.16
# step 89, training accuracy 0.16
# step 90, training accuracy 0.16
# step 91, training accuracy 0.16
# step 92, training accuracy 0.16
# step 93, training accuracy 0.16
# step 94, training accuracy 0.16
# step 95, training accuracy 0.16
# step 96, training accuracy 0.16
# step 97, training accuracy 0.16
# step 98, training accuracy 0.16
# step 99, training accuracy 0.16
# step 100, training accuracy 0.82
# step 101, training accuracy 0.82
# step 102, training accuracy 0.82
# step 103, training accuracy 0.82
# step 104, training accuracy 0.82
# step 105, training accuracy 0.82
# step 106, training accuracy 0.82
# step 107, training accuracy 0.82
# step 108, training accuracy 0.82
# step 109, training accuracy 0.82
# step 110, training accuracy 0.82
# step 111, training accuracy 0.82
# step 112, training accuracy 0.82
# step 113, training accuracy 0.82
# step 114, training accuracy 0.82
# step 115, training accuracy 0.82
# step 116, training accuracy 0.82
# step 117, training accuracy 0.82
# step 118, training accuracy 0.82
# step 119, training accuracy 0.82
# step 120, training accuracy 0.82
# step 121, training accuracy 0.82
# step 122, training accuracy 0.82
# step 123, training accuracy 0.82
# step 124, training accuracy 0.82
# step 125, training accuracy 0.82
# step 126, training accuracy 0.82
# step 127, training accuracy 0.82
# step 128, training accuracy 0.82
# step 129, training accuracy 0.82
# step 130, training accuracy 0.82
# step 131, training accuracy 0.82
# step 132, training accuracy 0.82
# step 133, training accuracy 0.82
# step 134, training accuracy 0.82
# step 135, training accuracy 0.82
# step 136, training accuracy 0.82
# step 137, training accuracy 0.82
# step 138, training accuracy 0.82
# step 139, training accuracy 0.82
# step 140, training accuracy 0.82
# step 141, training accuracy 0.82
# step 142, training accuracy 0.82
# step 143, training accuracy 0.82
# step 144, training accuracy 0.82
# step 145, training accuracy 0.82
# step 146, training accuracy 0.82
# step 147, training accuracy 0.82
# step 148, training accuracy 0.82
# step 149, training accuracy 0.82
# step 150, training accuracy 0.82
# step 151, training accuracy 0.82
# step 152, training accuracy 0.82
# step 153, training accuracy 0.82
# step 154, training accuracy 0.82
# step 155, training accuracy 0.82
# step 156, training accuracy 0.82
# step 157, training accuracy 0.82
# step 158, training accuracy 0.82
# step 159, training accuracy 0.82
# step 160, training accuracy 0.82
# step 161, training accuracy 0.82
# step 162, training accuracy 0.82
# step 163, training accuracy 0.82
# step 164, training accuracy 0.82
# step 165, training accuracy 0.82
# step 166, training accuracy 0.82
# step 167, training accuracy 0.82
# step 168, training accuracy 0.82
# step 169, training accuracy 0.82
# step 170, training accuracy 0.82
# step 171, training accuracy 0.82
# step 172, training accuracy 0.82
# step 173, training accuracy 0.82
# step 174, training accuracy 0.82
# step 175, training accuracy 0.82
# step 176, training accuracy 0.82
# step 177, training accuracy 0.82
# step 178, training accuracy 0.82
# step 179, training accuracy 0.82
# step 180, training accuracy 0.82
# step 181, training accuracy 0.82
# step 182, training accuracy 0.82
# step 183, training accuracy 0.82
# step 184, training accuracy 0.82
# step 185, training accuracy 0.82
# step 186, training accuracy 0.82
# step 187, training accuracy 0.82
# step 188, training accuracy 0.82
# step 189, training accuracy 0.82
# step 190, training accuracy 0.82
# step 191, training accuracy 0.82
# step 192, training accuracy 0.82
# step 193, training accuracy 0.82
# step 194, training accuracy 0.82
# step 195, training accuracy 0.82
# step 196, training accuracy 0.82
# step 197, training accuracy 0.82
# step 198, training accuracy 0.82
# step 199, training accuracy 0.82
# step 200, training accuracy 0.88
# step 201, training accuracy 0.88
# step 202, training accuracy 0.88
# step 203, training accuracy 0.88
# step 204, training accuracy 0.88
# step 205, training accuracy 0.88
# step 206, training accuracy 0.88
# step 207, training accuracy 0.88
# step 208, training accuracy 0.88
# step 209, training accuracy 0.88
# step 210, training accuracy 0.88
# step 211, training accuracy 0.88
# step 212, training accuracy 0.88
# step 213, training accuracy 0.88
# step 214, training accuracy 0.88
# step 215, training accuracy 0.88
# step 216, training accuracy 0.88
# step 217, training accuracy 0.88
# step 218, training accuracy 0.88
# step 219, training accuracy 0.88
# step 220, training accuracy 0.88
# step 221, training accuracy 0.88
# step 222, training accuracy 0.88
# step 223, training accuracy 0.88
# step 224, training accuracy 0.88
# step 225, training accuracy 0.88
# step 226, training accuracy 0.88
# step 227, training accuracy 0.88
# step 228, training accuracy 0.88
# step 229, training accuracy 0.88
# step 230, training accuracy 0.88
# step 231, training accuracy 0.88
# step 232, training accuracy 0.88
# step 233, training accuracy 0.88
# step 234, training accuracy 0.88
# step 235, training accuracy 0.88
# step 236, training accuracy 0.88
# step 237, training accuracy 0.88
# step 238, training accuracy 0.88
# step 239, training accuracy 0.88
# step 240, training accuracy 0.88
# step 241, training accuracy 0.88
# step 242, training accuracy 0.88
# step 243, training accuracy 0.88
# step 244, training accuracy 0.88
# step 245, training accuracy 0.88
# step 246, training accuracy 0.88
# step 247, training accuracy 0.88
# step 248, training accuracy 0.88
# step 249, training accuracy 0.88
# step 250, training accuracy 0.88
# step 251, training accuracy 0.88
# step 252, training accuracy 0.88
# step 253, training accuracy 0.88
# step 254, training accuracy 0.88
# step 255, training accuracy 0.88
# step 256, training accuracy 0.88
# step 257, training accuracy 0.88
# step 258, training accuracy 0.88
# step 259, training accuracy 0.88
# step 260, training accuracy 0.88
# step 261, training accuracy 0.88
# step 262, training accuracy 0.88
# step 263, training accuracy 0.88
# step 264, training accuracy 0.88
# step 265, training accuracy 0.88
# step 266, training accuracy 0.88
# step 267, training accuracy 0.88
# step 268, training accuracy 0.88
# step 269, training accuracy 0.88
# step 270, training accuracy 0.88
# step 271, training accuracy 0.88
# step 272, training accuracy 0.88
# step 273, training accuracy 0.88
# step 274, training accuracy 0.88
# step 275, training accuracy 0.88
# step 276, training accuracy 0.88
# step 277, training accuracy 0.88
# step 278, training accuracy 0.88
# step 279, training accuracy 0.88
# step 280, training accuracy 0.88
# step 281, training accuracy 0.88
# step 282, training accuracy 0.88
# step 283, training accuracy 0.88
# step 284, training accuracy 0.88
# step 285, training accuracy 0.88
# step 286, training accuracy 0.88
# step 287, training accuracy 0.88
# step 288, training accuracy 0.88
# step 289, training accuracy 0.88
# step 290, training accuracy 0.88
# step 291, training accuracy 0.88
# step 292, training accuracy 0.88
# step 293, training accuracy 0.88
# step 294, training accuracy 0.88
# step 295, training accuracy 0.88
# step 296, training accuracy 0.88
# step 297, training accuracy 0.88
# step 298, training accuracy 0.88
# step 299, training accuracy 0.88
# step 300, training accuracy 0.96
# step 301, training accuracy 0.96
# step 302, training accuracy 0.96
# step 303, training accuracy 0.96
# step 304, training accuracy 0.96
# step 305, training accuracy 0.96
# step 306, training accuracy 0.96
# step 307, training accuracy 0.96
# step 308, training accuracy 0.96
# step 309, training accuracy 0.96
# step 310, training accuracy 0.96
# step 311, training accuracy 0.96
# step 312, training accuracy 0.96
# step 313, training accuracy 0.96
# step 314, training accuracy 0.96
# step 315, training accuracy 0.96
# step 316, training accuracy 0.96
# step 317, training accuracy 0.96
# step 318, training accuracy 0.96
# step 319, training accuracy 0.96
# step 320, training accuracy 0.96
# step 321, training accuracy 0.96
# step 322, training accuracy 0.96
# step 323, training accuracy 0.96
# step 324, training accuracy 0.96
# step 325, training accuracy 0.96
# step 326, training accuracy 0.96
# step 327, training accuracy 0.96
# step 328, training accuracy 0.96
# step 329, training accuracy 0.96
# step 330, training accuracy 0.96
# step 331, training accuracy 0.96
# step 332, training accuracy 0.96
# step 333, training accuracy 0.96
# step 334, training accuracy 0.96
# step 335, training accuracy 0.96
# step 336, training accuracy 0.96
# step 337, training accuracy 0.96
# step 338, training accuracy 0.96
# step 339, training accuracy 0.96
# step 340, training accuracy 0.96
# step 341, training accuracy 0.96
# step 342, training accuracy 0.96
# step 343, training accuracy 0.96
# step 344, training accuracy 0.96
# step 345, training accuracy 0.96
# step 346, training accuracy 0.96
# step 347, training accuracy 0.96
# step 348, training accuracy 0.96
# step 349, training accuracy 0.96
# step 350, training accuracy 0.96
# step 351, training accuracy 0.96
# step 352, training accuracy 0.96
# step 353, training accuracy 0.96
# step 354, training accuracy 0.96
# step 355, training accuracy 0.96
# step 356, training accuracy 0.96
# step 357, training accuracy 0.96
# step 358, training accuracy 0.96
# step 359, training accuracy 0.96
# step 360, training accuracy 0.96
# step 361, training accuracy 0.96
# step 362, training accuracy 0.96
# step 363, training accuracy 0.96
# step 364, training accuracy 0.96
# step 365, training accuracy 0.96
# step 366, training accuracy 0.96
# step 367, training accuracy 0.96
# step 368, training accuracy 0.96
# step 369, training accuracy 0.96
# step 370, training accuracy 0.96
# step 371, training accuracy 0.96
# step 372, training accuracy 0.96
# step 373, training accuracy 0.96
# step 374, training accuracy 0.96
# step 375, training accuracy 0.96
# step 376, training accuracy 0.96
# step 377, training accuracy 0.96
# step 378, training accuracy 0.96
# step 379, training accuracy 0.96
# step 380, training accuracy 0.96
# step 381, training accuracy 0.96
# step 382, training accuracy 0.96
# step 383, training accuracy 0.96
# step 384, training accuracy 0.96
# step 385, training accuracy 0.96
# step 386, training accuracy 0.96
# step 387, training accuracy 0.96
# step 388, training accuracy 0.96
# step 389, training accuracy 0.96
# step 390, training accuracy 0.96
# step 391, training accuracy 0.96
# step 392, training accuracy 0.96
# step 393, training accuracy 0.96
# step 394, training accuracy 0.96
# step 395, training accuracy 0.96
# step 396, training accuracy 0.96
# step 397, training accuracy 0.96
# step 398, training accuracy 0.96
# step 399, training accuracy 0.96
# step 400, training accuracy 0.96
# step 401, training accuracy 0.96
# step 402, training accuracy 0.96
# step 403, training accuracy 0.96
# step 404, training accuracy 0.96
# step 405, training accuracy 0.96
# step 406, training accuracy 0.96
# step 407, training accuracy 0.96
# step 408, training accuracy 0.96
# step 409, training accuracy 0.96
# step 410, training accuracy 0.96
# step 411, training accuracy 0.96
# step 412, training accuracy 0.96
# step 413, training accuracy 0.96
# step 414, training accuracy 0.96
# step 415, training accuracy 0.96
# step 416, training accuracy 0.96
# step 417, training accuracy 0.96
# step 418, training accuracy 0.96
# step 419, training accuracy 0.96
# step 420, training accuracy 0.96
# step 421, training accuracy 0.96
# step 422, training accuracy 0.96
# step 423, training accuracy 0.96
# step 424, training accuracy 0.96
# step 425, training accuracy 0.96
# step 426, training accuracy 0.96
# step 427, training accuracy 0.96
# step 428, training accuracy 0.96
# step 429, training accuracy 0.96
# step 430, training accuracy 0.96
# step 431, training accuracy 0.96
# step 432, training accuracy 0.96
# step 433, training accuracy 0.96
# step 434, training accuracy 0.96
# step 435, training accuracy 0.96
# step 436, training accuracy 0.96
# step 437, training accuracy 0.96
# step 438, training accuracy 0.96
# step 439, training accuracy 0.96
# step 440, training accuracy 0.96
# step 441, training accuracy 0.96
# step 442, training accuracy 0.96
# step 443, training accuracy 0.96
# step 444, training accuracy 0.96
# step 445, training accuracy 0.96
# step 446, training accuracy 0.96
# step 447, training accuracy 0.96
# step 448, training accuracy 0.96
# step 449, training accuracy 0.96
# step 450, training accuracy 0.96
# step 451, training accuracy 0.96
# step 452, training accuracy 0.96
# step 453, training accuracy 0.96
# step 454, training accuracy 0.96
# step 455, training accuracy 0.96
# step 456, training accuracy 0.96
# step 457, training accuracy 0.96
# step 458, training accuracy 0.96
# step 459, training accuracy 0.96
# step 460, training accuracy 0.96
# step 461, training accuracy 0.96
# step 462, training accuracy 0.96
# step 463, training accuracy 0.96
# step 464, training accuracy 0.96
# step 465, training accuracy 0.96
# step 466, training accuracy 0.96
# step 467, training accuracy 0.96
# step 468, training accuracy 0.96
# step 469, training accuracy 0.96
# step 470, training accuracy 0.96
# step 471, training accuracy 0.96
# step 472, training accuracy 0.96
# step 473, training accuracy 0.96
# step 474, training accuracy 0.96
# step 475, training accuracy 0.96
# step 476, training accuracy 0.96
# step 477, training accuracy 0.96
# step 478, training accuracy 0.96
# step 479, training accuracy 0.96
# step 480, training accuracy 0.96
# step 481, training accuracy 0.96
# step 482, training accuracy 0.96
# step 483, training accuracy 0.96
# step 484, training accuracy 0.96
# step 485, training accuracy 0.96
# step 486, training accuracy 0.96
# step 487, training accuracy 0.96
# step 488, training accuracy 0.96
# step 489, training accuracy 0.96
# step 490, training accuracy 0.96
# step 491, training accuracy 0.96
# step 492, training accuracy 0.96
# step 493, training accuracy 0.96
# step 494, training accuracy 0.96
# step 495, training accuracy 0.96
# step 496, training accuracy 0.96
# step 497, training accuracy 0.96
# step 498, training accuracy 0.96
# step 499, training accuracy 0.96
# step 500, training accuracy 0.94
# step 501, training accuracy 0.94
# step 502, training accuracy 0.94
# step 503, training accuracy 0.94
# step 504, training accuracy 0.94
# step 505, training accuracy 0.94
# step 506, training accuracy 0.94
# step 507, training accuracy 0.94
# step 508, training accuracy 0.94
# step 509, training accuracy 0.94
# step 510, training accuracy 0.94
# step 511, training accuracy 0.94
# step 512, training accuracy 0.94
# step 513, training accuracy 0.94
# step 514, training accuracy 0.94
# step 515, training accuracy 0.94
# step 516, training accuracy 0.94
# step 517, training accuracy 0.94
# step 518, training accuracy 0.94
# step 519, training accuracy 0.94
# step 520, training accuracy 0.94
# step 521, training accuracy 0.94
# step 522, training accuracy 0.94
# step 523, training accuracy 0.94
# step 524, training accuracy 0.94
# step 525, training accuracy 0.94
# step 526, training accuracy 0.94
# step 527, training accuracy 0.94
# step 528, training accuracy 0.94
# step 529, training accuracy 0.94
# step 530, training accuracy 0.94
# step 531, training accuracy 0.94
# step 532, training accuracy 0.94
# step 533, training accuracy 0.94
# step 534, training accuracy 0.94
# step 535, training accuracy 0.94
# step 536, training accuracy 0.94
# step 537, training accuracy 0.94
# step 538, training accuracy 0.94
# step 539, training accuracy 0.94
# step 540, training accuracy 0.94
# step 541, training accuracy 0.94
# step 542, training accuracy 0.94
# step 543, training accuracy 0.94
# step 544, training accuracy 0.94
# step 545, training accuracy 0.94
# step 546, training accuracy 0.94
# step 547, training accuracy 0.94
# step 548, training accuracy 0.94
# step 549, training accuracy 0.94
# step 550, training accuracy 0.94
# step 551, training accuracy 0.94
# step 552, training accuracy 0.94
# step 553, training accuracy 0.94
# step 554, training accuracy 0.94
# step 555, training accuracy 0.94
# step 556, training accuracy 0.94
# step 557, training accuracy 0.94
# step 558, training accuracy 0.94
# step 559, training accuracy 0.94
# step 560, training accuracy 0.94
# step 561, training accuracy 0.94
# step 562, training accuracy 0.94
# step 563, training accuracy 0.94
# step 564, training accuracy 0.94
# step 565, training accuracy 0.94
# step 566, training accuracy 0.94
# step 567, training accuracy 0.94
# step 568, training accuracy 0.94
# step 569, training accuracy 0.94
# step 570, training accuracy 0.94
# step 571, training accuracy 0.94
# step 572, training accuracy 0.94
# step 573, training accuracy 0.94
# step 574, training accuracy 0.94
# step 575, training accuracy 0.94
# step 576, training accuracy 0.94
# step 577, training accuracy 0.94
# step 578, training accuracy 0.94
# step 579, training accuracy 0.94
# step 580, training accuracy 0.94
# step 581, training accuracy 0.94
# step 582, training accuracy 0.94
# step 583, training accuracy 0.94
# step 584, training accuracy 0.94
# step 585, training accuracy 0.94
# step 586, training accuracy 0.94
# step 587, training accuracy 0.94
# step 588, training accuracy 0.94
# step 589, training accuracy 0.94
# step 590, training accuracy 0.94
# step 591, training accuracy 0.94
# step 592, training accuracy 0.94
# step 593, training accuracy 0.94
# step 594, training accuracy 0.94
# step 595, training accuracy 0.94
# step 596, training accuracy 0.94
# step 597, training accuracy 0.94
# step 598, training accuracy 0.94
# step 599, training accuracy 0.94
# step 600, training accuracy 0.96
# step 601, training accuracy 0.96
# step 602, training accuracy 0.96
# step 603, training accuracy 0.96
# step 604, training accuracy 0.96
# step 605, training accuracy 0.96
# step 606, training accuracy 0.96
# step 607, training accuracy 0.96
# step 608, training accuracy 0.96
# step 609, training accuracy 0.96
# step 610, training accuracy 0.96
# step 611, training accuracy 0.96
# step 612, training accuracy 0.96
# step 613, training accuracy 0.96
# step 614, training accuracy 0.96
# step 615, training accuracy 0.96
# step 616, training accuracy 0.96
# step 617, training accuracy 0.96
# step 618, training accuracy 0.96
# step 619, training accuracy 0.96
# step 620, training accuracy 0.96
# step 621, training accuracy 0.96
# step 622, training accuracy 0.96
# step 623, training accuracy 0.96
# step 624, training accuracy 0.96
# step 625, training accuracy 0.96
# step 626, training accuracy 0.96
# step 627, training accuracy 0.96
# step 628, training accuracy 0.96
# step 629, training accuracy 0.96
# step 630, training accuracy 0.96
# step 631, training accuracy 0.96
# step 632, training accuracy 0.96
# step 633, training accuracy 0.96
# step 634, training accuracy 0.96
# step 635, training accuracy 0.96
# step 636, training accuracy 0.96
# step 637, training accuracy 0.96
# step 638, training accuracy 0.96
# step 639, training accuracy 0.96
# step 640, training accuracy 0.96
# step 641, training accuracy 0.96
# step 642, training accuracy 0.96
# step 643, training accuracy 0.96
# step 644, training accuracy 0.96
# step 645, training accuracy 0.96
# step 646, training accuracy 0.96
# step 647, training accuracy 0.96
# step 648, training accuracy 0.96
# step 649, training accuracy 0.96
# step 650, training accuracy 0.96
# step 651, training accuracy 0.96
# step 652, training accuracy 0.96
# step 653, training accuracy 0.96
# step 654, training accuracy 0.96
# step 655, training accuracy 0.96
# step 656, training accuracy 0.96
# step 657, training accuracy 0.96
# step 658, training accuracy 0.96
# step 659, training accuracy 0.96
# step 660, training accuracy 0.96
# step 661, training accuracy 0.96
# step 662, training accuracy 0.96
# step 663, training accuracy 0.96
# step 664, training accuracy 0.96
# step 665, training accuracy 0.96
# step 666, training accuracy 0.96
# step 667, training accuracy 0.96
# step 668, training accuracy 0.96
# step 669, training accuracy 0.96
# step 670, training accuracy 0.96
# step 671, training accuracy 0.96
# step 672, training accuracy 0.96
# step 673, training accuracy 0.96
# step 674, training accuracy 0.96
# step 675, training accuracy 0.96
# step 676, training accuracy 0.96
# step 677, training accuracy 0.96
# step 678, training accuracy 0.96
# step 679, training accuracy 0.96
# step 680, training accuracy 0.96
# step 681, training accuracy 0.96
# step 682, training accuracy 0.96
# step 683, training accuracy 0.96
# step 684, training accuracy 0.96
# step 685, training accuracy 0.96
# step 686, training accuracy 0.96
# step 687, training accuracy 0.96
# step 688, training accuracy 0.96
# step 689, training accuracy 0.96
# step 690, training accuracy 0.96
# step 691, training accuracy 0.96
# step 692, training accuracy 0.96
# step 693, training accuracy 0.96
# step 694, training accuracy 0.96
# step 695, training accuracy 0.96
# step 696, training accuracy 0.96
# step 697, training accuracy 0.96
# step 698, training accuracy 0.96
# step 699, training accuracy 0.96
# step 700, training accuracy 0.94
# step 701, training accuracy 0.94
# step 702, training accuracy 0.94
# step 703, training accuracy 0.94
# step 704, training accuracy 0.94
# step 705, training accuracy 0.94
# step 706, training accuracy 0.94
# step 707, training accuracy 0.94
# step 708, training accuracy 0.94
# step 709, training accuracy 0.94
# step 710, training accuracy 0.94
# step 711, training accuracy 0.94
# step 712, training accuracy 0.94
# step 713, training accuracy 0.94
# step 714, training accuracy 0.94
# step 715, training accuracy 0.94
# step 716, training accuracy 0.94
# step 717, training accuracy 0.94
# step 718, training accuracy 0.94
# step 719, training accuracy 0.94
# step 720, training accuracy 0.94
# step 721, training accuracy 0.94
# step 722, training accuracy 0.94
# step 723, training accuracy 0.94
# step 724, training accuracy 0.94
# step 725, training accuracy 0.94
# step 726, training accuracy 0.94
# step 727, training accuracy 0.94
# step 728, training accuracy 0.94
# step 729, training accuracy 0.94
# step 730, training accuracy 0.94
# step 731, training accuracy 0.94
# step 732, training accuracy 0.94
# step 733, training accuracy 0.94
# step 734, training accuracy 0.94
# step 735, training accuracy 0.94
# step 736, training accuracy 0.94
# step 737, training accuracy 0.94
# step 738, training accuracy 0.94
# step 739, training accuracy 0.94
# step 740, training accuracy 0.94
# step 741, training accuracy 0.94
# step 742, training accuracy 0.94
# step 743, training accuracy 0.94
# step 744, training accuracy 0.94
# step 745, training accuracy 0.94
# step 746, training accuracy 0.94
# step 747, training accuracy 0.94
# step 748, training accuracy 0.94
# step 749, training accuracy 0.94
# step 750, training accuracy 0.94
# step 751, training accuracy 0.94
# step 752, training accuracy 0.94
# step 753, training accuracy 0.94
# step 754, training accuracy 0.94
# step 755, training accuracy 0.94
# step 756, training accuracy 0.94
# step 757, training accuracy 0.94
# step 758, training accuracy 0.94
# step 759, training accuracy 0.94
# step 760, training accuracy 0.94
# step 761, training accuracy 0.94
# step 762, training accuracy 0.94
# step 763, training accuracy 0.94
# step 764, training accuracy 0.94
# step 765, training accuracy 0.94
# step 766, training accuracy 0.94
# step 767, training accuracy 0.94
# step 768, training accuracy 0.94
# step 769, training accuracy 0.94
# step 770, training accuracy 0.94
# step 771, training accuracy 0.94
# step 772, training accuracy 0.94
# step 773, training accuracy 0.94
# step 774, training accuracy 0.94
# step 775, training accuracy 0.94
# step 776, training accuracy 0.94
# step 777, training accuracy 0.94
# step 778, training accuracy 0.94
# step 779, training accuracy 0.94
# step 780, training accuracy 0.94
# step 781, training accuracy 0.94
# step 782, training accuracy 0.94
# step 783, training accuracy 0.94
# step 784, training accuracy 0.94
# step 785, training accuracy 0.94
# step 786, training accuracy 0.94
# step 787, training accuracy 0.94
# step 788, training accuracy 0.94
# step 789, training accuracy 0.94
# step 790, training accuracy 0.94
# step 791, training accuracy 0.94
# step 792, training accuracy 0.94
# step 793, training accuracy 0.94
# step 794, training accuracy 0.94
# step 795, training accuracy 0.94
# step 796, training accuracy 0.94
# step 797, training accuracy 0.94
# step 798, training accuracy 0.94
# step 799, training accuracy 0.94
# step 800, training accuracy 0.92
# step 801, training accuracy 0.92
# step 802, training accuracy 0.92
# step 803, training accuracy 0.92
# step 804, training accuracy 0.92
# step 805, training accuracy 0.92
# step 806, training accuracy 0.92
# step 807, training accuracy 0.92
# step 808, training accuracy 0.92
# step 809, training accuracy 0.92
# step 810, training accuracy 0.92
# step 811, training accuracy 0.92
# step 812, training accuracy 0.92
# step 813, training accuracy 0.92
# step 814, training accuracy 0.92
# step 815, training accuracy 0.92
# step 816, training accuracy 0.92
# step 817, training accuracy 0.92
# step 818, training accuracy 0.92
# step 819, training accuracy 0.92
# step 820, training accuracy 0.92
# step 821, training accuracy 0.92
# step 822, training accuracy 0.92
# step 823, training accuracy 0.92
# step 824, training accuracy 0.92
# step 825, training accuracy 0.92
# step 826, training accuracy 0.92
# step 827, training accuracy 0.92
# step 828, training accuracy 0.92
# step 829, training accuracy 0.92
# step 830, training accuracy 0.92
# step 831, training accuracy 0.92
# step 832, training accuracy 0.92
# step 833, training accuracy 0.92
# step 834, training accuracy 0.92
# step 835, training accuracy 0.92
# step 836, training accuracy 0.92
# step 837, training accuracy 0.92
# step 838, training accuracy 0.92
# step 839, training accuracy 0.92
# step 840, training accuracy 0.92
# step 841, training accuracy 0.92
# step 842, training accuracy 0.92
# step 843, training accuracy 0.92
# step 844, training accuracy 0.92
# step 845, training accuracy 0.92
# step 846, training accuracy 0.92
# step 847, training accuracy 0.92
# step 848, training accuracy 0.92
# step 849, training accuracy 0.92
# step 850, training accuracy 0.92
# step 851, training accuracy 0.92
# step 852, training accuracy 0.92
# step 853, training accuracy 0.92
# step 854, training accuracy 0.92
# step 855, training accuracy 0.92
# step 856, training accuracy 0.92
# step 857, training accuracy 0.92
# step 858, training accuracy 0.92
# step 859, training accuracy 0.92
# step 860, training accuracy 0.92
# step 861, training accuracy 0.92
# step 862, training accuracy 0.92
# step 863, training accuracy 0.92
# step 864, training accuracy 0.92
# step 865, training accuracy 0.92
# step 866, training accuracy 0.92
# step 867, training accuracy 0.92
# step 868, training accuracy 0.92
# step 869, training accuracy 0.92
# step 870, training accuracy 0.92
# step 871, training accuracy 0.92
# step 872, training accuracy 0.92
# step 873, training accuracy 0.92
# step 874, training accuracy 0.92
# step 875, training accuracy 0.92
# step 876, training accuracy 0.92
# step 877, training accuracy 0.92
# step 878, training accuracy 0.92
# step 879, training accuracy 0.92
# step 880, training accuracy 0.92
# step 881, training accuracy 0.92
# step 882, training accuracy 0.92
# step 883, training accuracy 0.92
# step 884, training accuracy 0.92
# step 885, training accuracy 0.92
# step 886, training accuracy 0.92
# step 887, training accuracy 0.92
# step 888, training accuracy 0.92
# step 889, training accuracy 0.92
# step 890, training accuracy 0.92
# step 891, training accuracy 0.92
# step 892, training accuracy 0.92
# step 893, training accuracy 0.92
# step 894, training accuracy 0.92
# step 895, training accuracy 0.92
# step 896, training accuracy 0.92
# step 897, training accuracy 0.92
# step 898, training accuracy 0.92
# step 899, training accuracy 0.92
# step 900, training accuracy 0.96
# step 901, training accuracy 0.96
# step 902, training accuracy 0.96
# step 903, training accuracy 0.96
# step 904, training accuracy 0.96
# step 905, training accuracy 0.96
# step 906, training accuracy 0.96
# step 907, training accuracy 0.96
# step 908, training accuracy 0.96
# step 909, training accuracy 0.96
# step 910, training accuracy 0.96
# step 911, training accuracy 0.96
# step 912, training accuracy 0.96
# step 913, training accuracy 0.96
# step 914, training accuracy 0.96
# step 915, training accuracy 0.96
# step 916, training accuracy 0.96
# step 917, training accuracy 0.96
# step 918, training accuracy 0.96
# step 919, training accuracy 0.96
# step 920, training accuracy 0.96
# step 921, training accuracy 0.96
# step 922, training accuracy 0.96
# step 923, training accuracy 0.96
# step 924, training accuracy 0.96
# step 925, training accuracy 0.96
# step 926, training accuracy 0.96
# step 927, training accuracy 0.96
# step 928, training accuracy 0.96
# step 929, training accuracy 0.96
# step 930, training accuracy 0.96
# step 931, training accuracy 0.96
# step 932, training accuracy 0.96
# step 933, training accuracy 0.96
# step 934, training accuracy 0.96
# step 935, training accuracy 0.96
# step 936, training accuracy 0.96
# step 937, training accuracy 0.96
# step 938, training accuracy 0.96
# step 939, training accuracy 0.96
# step 940, training accuracy 0.96
# step 941, training accuracy 0.96
# step 942, training accuracy 0.96
# step 943, training accuracy 0.96
# step 944, training accuracy 0.96
# step 945, training accuracy 0.96
# step 946, training accuracy 0.96
# step 947, training accuracy 0.96
# step 948, training accuracy 0.96
# step 949, training accuracy 0.96
# step 950, training accuracy 0.96
# step 951, training accuracy 0.96
# step 952, training accuracy 0.96
# step 953, training accuracy 0.96
# step 954, training accuracy 0.96
# step 955, training accuracy 0.96
# step 956, training accuracy 0.96
# step 957, training accuracy 0.96
# step 958, training accuracy 0.96
# step 959, training accuracy 0.96
# step 960, training accuracy 0.96
# step 961, training accuracy 0.96
# step 962, training accuracy 0.96
# step 963, training accuracy 0.96
# step 964, training accuracy 0.96
# step 965, training accuracy 0.96
# step 966, training accuracy 0.96
# step 967, training accuracy 0.96
# step 968, training accuracy 0.96
# step 969, training accuracy 0.96
# step 970, training accuracy 0.96
# step 971, training accuracy 0.96
# step 972, training accuracy 0.96
# step 973, training accuracy 0.96
# step 974, training accuracy 0.96
# step 975, training accuracy 0.96
# step 976, training accuracy 0.96
# step 977, training accuracy 0.96
# step 978, training accuracy 0.96
# step 979, training accuracy 0.96
# step 980, training accuracy 0.96
# step 981, training accuracy 0.96
# step 982, training accuracy 0.96
# step 983, training accuracy 0.96
# step 984, training accuracy 0.96
# step 985, training accuracy 0.96
# step 986, training accuracy 0.96
# step 987, training accuracy 0.96
# step 988, training accuracy 0.96
# step 989, training accuracy 0.96
# step 990, training accuracy 0.96
# step 991, training accuracy 0.96
# step 992, training accuracy 0.96
# step 993, training accuracy 0.96
# step 994, training accuracy 0.96
# step 995, training accuracy 0.96
# step 996, training accuracy 0.96
# step 997, training accuracy 0.96
# step 998, training accuracy 0.96
# step 999, training accuracy 0.96
# step 1000, training accuracy 0.96
# step 1001, training accuracy 0.96
# step 1002, training accuracy 0.96
# step 1003, training accuracy 0.96
# step 1004, training accuracy 0.96
# step 1005, training accuracy 0.96
# step 1006, training accuracy 0.96
# step 1007, training accuracy 0.96
# step 1008, training accuracy 0.96
# step 1009, training accuracy 0.96
# step 1010, training accuracy 0.96
# step 1011, training accuracy 0.96
# step 1012, training accuracy 0.96
# step 1013, training accuracy 0.96
# step 1014, training accuracy 0.96
# step 1015, training accuracy 0.96
# step 1016, training accuracy 0.96
# step 1017, training accuracy 0.96
# step 1018, training accuracy 0.96
# step 1019, training accuracy 0.96
# step 1020, training accuracy 0.96
# step 1021, training accuracy 0.96
# step 1022, training accuracy 0.96
# step 1023, training accuracy 0.96
# step 1024, training accuracy 0.96
# step 1025, training accuracy 0.96
# step 1026, training accuracy 0.96
# step 1027, training accuracy 0.96
# step 1028, training accuracy 0.96
# step 1029, training accuracy 0.96
# step 1030, training accuracy 0.96
# step 1031, training accuracy 0.96
# step 1032, training accuracy 0.96
# step 1033, training accuracy 0.96
# step 1034, training accuracy 0.96
# step 1035, training accuracy 0.96
# step 1036, training accuracy 0.96
# step 1037, training accuracy 0.96
# step 1038, training accuracy 0.96
# step 1039, training accuracy 0.96
# step 1040, training accuracy 0.96
# step 1041, training accuracy 0.96
# step 1042, training accuracy 0.96
# step 1043, training accuracy 0.96
# step 1044, training accuracy 0.96
# step 1045, training accuracy 0.96
# step 1046, training accuracy 0.96
# step 1047, training accuracy 0.96
# step 1048, training accuracy 0.96
# step 1049, training accuracy 0.96
# step 1050, training accuracy 0.96
# step 1051, training accuracy 0.96
# step 1052, training accuracy 0.96
# step 1053, training accuracy 0.96
# step 1054, training accuracy 0.96
# step 1055, training accuracy 0.96
# step 1056, training accuracy 0.96
# step 1057, training accuracy 0.96
# step 1058, training accuracy 0.96
# step 1059, training accuracy 0.96
# step 1060, training accuracy 0.96
# step 1061, training accuracy 0.96
# step 1062, training accuracy 0.96
# step 1063, training accuracy 0.96
# step 1064, training accuracy 0.96
# step 1065, training accuracy 0.96
# step 1066, training accuracy 0.96
# step 1067, training accuracy 0.96
# step 1068, training accuracy 0.96
# step 1069, training accuracy 0.96
# step 1070, training accuracy 0.96
# step 1071, training accuracy 0.96
# step 1072, training accuracy 0.96
# step 1073, training accuracy 0.96
# step 1074, training accuracy 0.96
# step 1075, training accuracy 0.96
# step 1076, training accuracy 0.96
# step 1077, training accuracy 0.96
# step 1078, training accuracy 0.96
# step 1079, training accuracy 0.96
# step 1080, training accuracy 0.96
# step 1081, training accuracy 0.96
# step 1082, training accuracy 0.96
# step 1083, training accuracy 0.96
# step 1084, training accuracy 0.96
# step 1085, training accuracy 0.96
# step 1086, training accuracy 0.96
# step 1087, training accuracy 0.96
# step 1088, training accuracy 0.96
# step 1089, training accuracy 0.96
# step 1090, training accuracy 0.96
# step 1091, training accuracy 0.96
# step 1092, training accuracy 0.96
# step 1093, training accuracy 0.96
# step 1094, training accuracy 0.96
# step 1095, training accuracy 0.96
# step 1096, training accuracy 0.96
# step 1097, training accuracy 0.96
# step 1098, training accuracy 0.96
# step 1099, training accuracy 0.96
# step 1100, training accuracy 0.96
# step 1101, training accuracy 0.96
# step 1102, training accuracy 0.96
# step 1103, training accuracy 0.96
# step 1104, training accuracy 0.96
# step 1105, training accuracy 0.96
# step 1106, training accuracy 0.96
# step 1107, training accuracy 0.96
# step 1108, training accuracy 0.96
# step 1109, training accuracy 0.96
# step 1110, training accuracy 0.96
# step 1111, training accuracy 0.96
# step 1112, training accuracy 0.96
# step 1113, training accuracy 0.96
# step 1114, training accuracy 0.96
# step 1115, training accuracy 0.96
# step 1116, training accuracy 0.96
# step 1117, training accuracy 0.96
# step 1118, training accuracy 0.96
# step 1119, training accuracy 0.96
# step 1120, training accuracy 0.96
# step 1121, training accuracy 0.96
# step 1122, training accuracy 0.96
# step 1123, training accuracy 0.96
# step 1124, training accuracy 0.96
# step 1125, training accuracy 0.96
# step 1126, training accuracy 0.96
# step 1127, training accuracy 0.96
# step 1128, training accuracy 0.96
# step 1129, training accuracy 0.96
# step 1130, training accuracy 0.96
# step 1131, training accuracy 0.96
# step 1132, training accuracy 0.96
# step 1133, training accuracy 0.96
# step 1134, training accuracy 0.96
# step 1135, training accuracy 0.96
# step 1136, training accuracy 0.96
# step 1137, training accuracy 0.96
# step 1138, training accuracy 0.96
# step 1139, training accuracy 0.96
# step 1140, training accuracy 0.96
# step 1141, training accuracy 0.96
# step 1142, training accuracy 0.96
# step 1143, training accuracy 0.96
# step 1144, training accuracy 0.96
# step 1145, training accuracy 0.96
# step 1146, training accuracy 0.96
# step 1147, training accuracy 0.96
# step 1148, training accuracy 0.96
# step 1149, training accuracy 0.96
# step 1150, training accuracy 0.96
# step 1151, training accuracy 0.96
# step 1152, training accuracy 0.96
# step 1153, training accuracy 0.96
# step 1154, training accuracy 0.96
# step 1155, training accuracy 0.96
# step 1156, training accuracy 0.96
# step 1157, training accuracy 0.96
# step 1158, training accuracy 0.96
# step 1159, training accuracy 0.96
# step 1160, training accuracy 0.96
# step 1161, training accuracy 0.96
# step 1162, training accuracy 0.96
# step 1163, training accuracy 0.96
# step 1164, training accuracy 0.96
# step 1165, training accuracy 0.96
# step 1166, training accuracy 0.96
# step 1167, training accuracy 0.96
# step 1168, training accuracy 0.96
# step 1169, training accuracy 0.96
# step 1170, training accuracy 0.96
# step 1171, training accuracy 0.96
# step 1172, training accuracy 0.96
# step 1173, training accuracy 0.96
# step 1174, training accuracy 0.96
# step 1175, training accuracy 0.96
# step 1176, training accuracy 0.96
# step 1177, training accuracy 0.96
# step 1178, training accuracy 0.96
# step 1179, training accuracy 0.96
# step 1180, training accuracy 0.96
# step 1181, training accuracy 0.96
# step 1182, training accuracy 0.96
# step 1183, training accuracy 0.96
# step 1184, training accuracy 0.96
# step 1185, training accuracy 0.96
# step 1186, training accuracy 0.96
# step 1187, training accuracy 0.96
# step 1188, training accuracy 0.96
# step 1189, training accuracy 0.96
# step 1190, training accuracy 0.96
# step 1191, training accuracy 0.96
# step 1192, training accuracy 0.96
# step 1193, training accuracy 0.96
# step 1194, training accuracy 0.96
# step 1195, training accuracy 0.96
# step 1196, training accuracy 0.96
# step 1197, training accuracy 0.96
# step 1198, training accuracy 0.96
# step 1199, training accuracy 0.96
# step 1200, training accuracy 0.98
# step 1201, training accuracy 0.98
# step 1202, training accuracy 0.98
# step 1203, training accuracy 0.98
# step 1204, training accuracy 0.98
# step 1205, training accuracy 0.98
# step 1206, training accuracy 0.98
# step 1207, training accuracy 0.98
# step 1208, training accuracy 0.98
# step 1209, training accuracy 0.98
# step 1210, training accuracy 0.98
# step 1211, training accuracy 0.98
# step 1212, training accuracy 0.98
# step 1213, training accuracy 0.98
# step 1214, training accuracy 0.98
# step 1215, training accuracy 0.98
# step 1216, training accuracy 0.98
# step 1217, training accuracy 0.98
# step 1218, training accuracy 0.98
# step 1219, training accuracy 0.98
# step 1220, training accuracy 0.98
# step 1221, training accuracy 0.98
# step 1222, training accuracy 0.98
# step 1223, training accuracy 0.98
# step 1224, training accuracy 0.98
# step 1225, training accuracy 0.98
# step 1226, training accuracy 0.98
# step 1227, training accuracy 0.98
# step 1228, training accuracy 0.98
# step 1229, training accuracy 0.98
# step 1230, training accuracy 0.98
# step 1231, training accuracy 0.98
# step 1232, training accuracy 0.98
# step 1233, training accuracy 0.98
# step 1234, training accuracy 0.98
# step 1235, training accuracy 0.98
# step 1236, training accuracy 0.98
# step 1237, training accuracy 0.98
# step 1238, training accuracy 0.98
# step 1239, training accuracy 0.98
# step 1240, training accuracy 0.98
# step 1241, training accuracy 0.98
# step 1242, training accuracy 0.98
# step 1243, training accuracy 0.98
# step 1244, training accuracy 0.98
# step 1245, training accuracy 0.98
# step 1246, training accuracy 0.98
# step 1247, training accuracy 0.98
# step 1248, training accuracy 0.98
# step 1249, training accuracy 0.98
# step 1250, training accuracy 0.98
# step 1251, training accuracy 0.98
# step 1252, training accuracy 0.98
# step 1253, training accuracy 0.98
# step 1254, training accuracy 0.98
# step 1255, training accuracy 0.98
# step 1256, training accuracy 0.98
# step 1257, training accuracy 0.98
# step 1258, training accuracy 0.98
# step 1259, training accuracy 0.98
# step 1260, training accuracy 0.98
# step 1261, training accuracy 0.98
# step 1262, training accuracy 0.98
# step 1263, training accuracy 0.98
# step 1264, training accuracy 0.98
# step 1265, training accuracy 0.98
# step 1266, training accuracy 0.98
# step 1267, training accuracy 0.98
# step 1268, training accuracy 0.98
# step 1269, training accuracy 0.98
# step 1270, training accuracy 0.98
# step 1271, training accuracy 0.98
# step 1272, training accuracy 0.98
# step 1273, training accuracy 0.98
# step 1274, training accuracy 0.98
# step 1275, training accuracy 0.98
# step 1276, training accuracy 0.98
# step 1277, training accuracy 0.98
# step 1278, training accuracy 0.98
# step 1279, training accuracy 0.98
# step 1280, training accuracy 0.98
# step 1281, training accuracy 0.98
# step 1282, training accuracy 0.98
# step 1283, training accuracy 0.98
# step 1284, training accuracy 0.98
# step 1285, training accuracy 0.98
# step 1286, training accuracy 0.98
# step 1287, training accuracy 0.98
# step 1288, training accuracy 0.98
# step 1289, training accuracy 0.98
# step 1290, training accuracy 0.98
# step 1291, training accuracy 0.98
# step 1292, training accuracy 0.98
# step 1293, training accuracy 0.98
# step 1294, training accuracy 0.98
# step 1295, training accuracy 0.98
# step 1296, training accuracy 0.98
# step 1297, training accuracy 0.98
# step 1298, training accuracy 0.98
# step 1299, training accuracy 0.98
# step 1300, training accuracy 1
# step 1301, training accuracy 1
# step 1302, training accuracy 1
# step 1303, training accuracy 1
# step 1304, training accuracy 1
# step 1305, training accuracy 1
# step 1306, training accuracy 1
# step 1307, training accuracy 1
# step 1308, training accuracy 1
# step 1309, training accuracy 1
# step 1310, training accuracy 1
# step 1311, training accuracy 1
# step 1312, training accuracy 1
# step 1313, training accuracy 1
# step 1314, training accuracy 1
# step 1315, training accuracy 1
# step 1316, training accuracy 1
# step 1317, training accuracy 1
# step 1318, training accuracy 1
# step 1319, training accuracy 1
# step 1320, training accuracy 1
# step 1321, training accuracy 1
# step 1322, training accuracy 1
# step 1323, training accuracy 1
# step 1324, training accuracy 1
# step 1325, training accuracy 1
# step 1326, training accuracy 1
# step 1327, training accuracy 1
# step 1328, training accuracy 1
# step 1329, training accuracy 1
# step 1330, training accuracy 1
# step 1331, training accuracy 1
# step 1332, training accuracy 1
# step 1333, training accuracy 1
# step 1334, training accuracy 1
# step 1335, training accuracy 1
# step 1336, training accuracy 1
# step 1337, training accuracy 1
# step 1338, training accuracy 1
# step 1339, training accuracy 1
# step 1340, training accuracy 1
# step 1341, training accuracy 1
# step 1342, training accuracy 1
# step 1343, training accuracy 1
# step 1344, training accuracy 1
# step 1345, training accuracy 1
# step 1346, training accuracy 1
# step 1347, training accuracy 1
# step 1348, training accuracy 1
# step 1349, training accuracy 1
# step 1350, training accuracy 1
# step 1351, training accuracy 1
# step 1352, training accuracy 1
# step 1353, training accuracy 1
# step 1354, training accuracy 1
# step 1355, training accuracy 1
# step 1356, training accuracy 1
# step 1357, training accuracy 1
# step 1358, training accuracy 1
# step 1359, training accuracy 1
# step 1360, training accuracy 1
# step 1361, training accuracy 1
# step 1362, training accuracy 1
# step 1363, training accuracy 1
# step 1364, training accuracy 1
# step 1365, training accuracy 1
# step 1366, training accuracy 1
# step 1367, training accuracy 1
# step 1368, training accuracy 1
# step 1369, training accuracy 1
# step 1370, training accuracy 1
# step 1371, training accuracy 1
# step 1372, training accuracy 1
# step 1373, training accuracy 1
# step 1374, training accuracy 1
# step 1375, training accuracy 1
# step 1376, training accuracy 1
# step 1377, training accuracy 1
# step 1378, training accuracy 1
# step 1379, training accuracy 1
# step 1380, training accuracy 1
# step 1381, training accuracy 1
# step 1382, training accuracy 1
# step 1383, training accuracy 1
# step 1384, training accuracy 1
# step 1385, training accuracy 1
# step 1386, training accuracy 1
# step 1387, training accuracy 1
# step 1388, training accuracy 1
# step 1389, training accuracy 1
# step 1390, training accuracy 1
# step 1391, training accuracy 1
# step 1392, training accuracy 1
# step 1393, training accuracy 1
# step 1394, training accuracy 1
# step 1395, training accuracy 1
# step 1396, training accuracy 1
# step 1397, training accuracy 1
# step 1398, training accuracy 1
# step 1399, training accuracy 1
# step 1400, training accuracy 0.98
# step 1401, training accuracy 0.98
# step 1402, training accuracy 0.98
# step 1403, training accuracy 0.98
# step 1404, training accuracy 0.98
# step 1405, training accuracy 0.98
# step 1406, training accuracy 0.98
# step 1407, training accuracy 0.98
# step 1408, training accuracy 0.98
# step 1409, training accuracy 0.98
# step 1410, training accuracy 0.98
# step 1411, training accuracy 0.98
# step 1412, training accuracy 0.98
# step 1413, training accuracy 0.98
# step 1414, training accuracy 0.98
# step 1415, training accuracy 0.98
# step 1416, training accuracy 0.98
# step 1417, training accuracy 0.98
# step 1418, training accuracy 0.98
# step 1419, training accuracy 0.98
# step 1420, training accuracy 0.98
# step 1421, training accuracy 0.98
# step 1422, training accuracy 0.98
# step 1423, training accuracy 0.98
# step 1424, training accuracy 0.98
# step 1425, training accuracy 0.98
# step 1426, training accuracy 0.98
# step 1427, training accuracy 0.98
# step 1428, training accuracy 0.98
# step 1429, training accuracy 0.98
# step 1430, training accuracy 0.98
# step 1431, training accuracy 0.98
# step 1432, training accuracy 0.98
# step 1433, training accuracy 0.98
# step 1434, training accuracy 0.98
# step 1435, training accuracy 0.98
# step 1436, training accuracy 0.98
# step 1437, training accuracy 0.98
# step 1438, training accuracy 0.98
# step 1439, training accuracy 0.98
# step 1440, training accuracy 0.98
# step 1441, training accuracy 0.98
# step 1442, training accuracy 0.98
# step 1443, training accuracy 0.98
# step 1444, training accuracy 0.98
# step 1445, training accuracy 0.98
# step 1446, training accuracy 0.98
# step 1447, training accuracy 0.98
# step 1448, training accuracy 0.98
# step 1449, training accuracy 0.98
# step 1450, training accuracy 0.98
# step 1451, training accuracy 0.98
# step 1452, training accuracy 0.98
# ...
# step 1930, training accuracy 1
# step 1931, training accuracy 1
# step 1932, training accuracy 1
# step 1933, training accuracy 1
# step 1934, training accuracy 1
# step 1935, training accuracy 1
# step 1936, training accuracy 1
# step 1937, training accuracy 1
# step 1938, training accuracy 1
# step 1939, training accuracy 1
# step 1940, training accuracy 1
# step 1941, training accuracy 1
# step 1942, training accuracy 1
# step 1943, training accuracy 1
# step 1944, training accuracy 1
# step 1945, training accuracy 1
# step 1946, training accuracy 1
# step 1947, training accuracy 1
# step 1948, training accuracy 1
# step 1949, training accuracy 1
# step 1950, training accuracy 1
# step 1951, training accuracy 1
# step 1952, training accuracy 1
# step 1953, training accuracy 1
# step 1954, training accuracy 1
# step 1955, training accuracy 1
# step 1956, training accuracy 1
# step 1957, training accuracy 1
# step 1958, training accuracy 1
# step 1959, training accuracy 1
# step 1960, training accuracy 1
# step 1961, training accuracy 1
# step 1962, training accuracy 1
# step 1963, training accuracy 1
# step 1964, training accuracy 1
# step 1965, training accuracy 1
# step 1966, training accuracy 1
# step 1967, training accuracy 1
# step 1968, training accuracy 1
# step 1969, training accuracy 1
# step 1970, training accuracy 1
# step 1971, training accuracy 1
# step 1972, training accuracy 1
# step 1973, training accuracy 1
# step 1974, training accuracy 1
# step 1975, training accuracy 1
# step 1976, training accuracy 1
# step 1977, training accuracy 1
# step 1978, training accuracy 1
# step 1979, training accuracy 1
# step 1980, training accuracy 1
# step 1981, training accuracy 1
# step 1982, training accuracy 1
# step 1983, training accuracy 1
# step 1984, training accuracy 1
# step 1985, training accuracy 1
# step 1986, training accuracy 1
# step 1987, training accuracy 1
# step 1988, training accuracy 1
# step 1989, training accuracy 1
# step 1990, training accuracy 1
# step 1991, training accuracy 1
# step 1992, training accuracy 1
# step 1993, training accuracy 1
# step 1994, training accuracy 1
# step 1995, training accuracy 1
# step 1996, training accuracy 1
# step 1997, training accuracy 1
# step 1998, training accuracy 1
# step 1999, training accuracy 1
# step 2000, training accuracy 0.98
# step 2001, training accuracy 0.98
# step 2002, training accuracy 0.98
# step 2003, training accuracy 0.98
# step 2004, training accuracy 0.98
# step 2005, training accuracy 0.98
# step 2006, training accuracy 0.98
# step 2007, training accuracy 0.98
# step 2008, training accuracy 0.98
# step 2009, training accuracy 0.98
# step 2010, training accuracy 0.98
# step 2011, training accuracy 0.98
# step 2012, training accuracy 0.98
# step 2013, training accuracy 0.98
# step 2014, training accuracy 0.98
# step 2015, training accuracy 0.98
# step 2016, training accuracy 0.98
# step 2017, training accuracy 0.98
# step 2018, training accuracy 0.98
# step 2019, training accuracy 0.98
# step 2020, training accuracy 0.98
# step 2021, training accuracy 0.98
# step 2022, training accuracy 0.98
# step 2023, training accuracy 0.98
# step 2024, training accuracy 0.98
# step 2025, training accuracy 0.98
# step 2026, training accuracy 0.98
# step 2027, training accuracy 0.98
# step 2028, training accuracy 0.98
# step 2029, training accuracy 0.98
# step 2030, training accuracy 0.98
# step 2031, training accuracy 0.98
# step 2032, training accuracy 0.98
# step 2033, training accuracy 0.98
# step 2034, training accuracy 0.98
# step 2035, training accuracy 0.98
# step 2036, training accuracy 0.98
# step 2037, training accuracy 0.98
# step 2038, training accuracy 0.98
# step 2039, training accuracy 0.98
# step 2040, training accuracy 0.98
# step 2041, training accuracy 0.98
# step 2042, training accuracy 0.98
# step 2043, training accuracy 0.98
# step 2044, training accuracy 0.98
# step 2045, training accuracy 0.98
# step 2046, training accuracy 0.98
# step 2047, training accuracy 0.98
# step 2048, training accuracy 0.98
# step 2049, training accuracy 0.98
# step 2050, training accuracy 0.98
# step 2051, training accuracy 0.98
# step 2052, training accuracy 0.98
# step 2053, training accuracy 0.98
# step 2054, training accuracy 0.98
# step 2055, training accuracy 0.98
# step 2056, training accuracy 0.98
# step 2057, training accuracy 0.98
# step 2058, training accuracy 0.98
# step 2059, training accuracy 0.98
# step 2060, training accuracy 0.98
# step 2061, training accuracy 0.98
# step 2062, training accuracy 0.98
# step 2063, training accuracy 0.98
# step 2064, training accuracy 0.98
# step 2065, training accuracy 0.98
# step 2066, training accuracy 0.98
# step 2067, training accuracy 0.98
# step 2068, training accuracy 0.98
# step 2069, training accuracy 0.98
# step 2070, training accuracy 0.98
# step 2071, training accuracy 0.98
# step 2072, training accuracy 0.98
# step 2073, training accuracy 0.98
# step 2074, training accuracy 0.98
# step 2075, training accuracy 0.98
# step 2076, training accuracy 0.98
# step 2077, training accuracy 0.98
# step 2078, training accuracy 0.98
# step 2079, training accuracy 0.98
# step 2080, training accuracy 0.98
# step 2081, training accuracy 0.98
# step 2082, training accuracy 0.98
# step 2083, training accuracy 0.98
# step 2084, training accuracy 0.98
# step 2085, training accuracy 0.98
# step 2086, training accuracy 0.98
# step 2087, training accuracy 0.98
# step 2088, training accuracy 0.98
# step 2089, training accuracy 0.98
# step 2090, training accuracy 0.98
# step 2091, training accuracy 0.98
# step 2092, training accuracy 0.98
# step 2093, training accuracy 0.98
# step 2094, training accuracy 0.98
# step 2095, training accuracy 0.98
# step 2096, training accuracy 0.98
# step 2097, training accuracy 0.98
# step 2098, training accuracy 0.98
# step 2099, training accuracy 0.98
# step 2100, training accuracy 0.96
# step 2101, training accuracy 0.96
# step 2102, training accuracy 0.96
# step 2103, training accuracy 0.96
# step 2104, training accuracy 0.96
# step 2105, training accuracy 0.96
# step 2106, training accuracy 0.96
# step 2107, training accuracy 0.96
# step 2108, training accuracy 0.96
# step 2109, training accuracy 0.96
# step 2110, training accuracy 0.96
# step 2111, training accuracy 0.96
# step 2112, training accuracy 0.96
# step 2113, training accuracy 0.96
# step 2114, training accuracy 0.96
# step 2115, training accuracy 0.96
# step 2116, training accuracy 0.96
# step 2117, training accuracy 0.96
# step 2118, training accuracy 0.96
# step 2119, training accuracy 0.96
# step 2120, training accuracy 0.96
# step 2121, training accuracy 0.96
# step 2122, training accuracy 0.96
# step 2123, training accuracy 0.96
# step 2124, training accuracy 0.96
# step 2125, training accuracy 0.96
# step 2126, training accuracy 0.96
# step 2127, training accuracy 0.96
# step 2128, training accuracy 0.96
# step 2129, training accuracy 0.96
# step 2130, training accuracy 0.96
# step 2131, training accuracy 0.96
# step 2132, training accuracy 0.96
# step 2133, training accuracy 0.96
# step 2134, training accuracy 0.96
# step 2135, training accuracy 0.96
# step 2136, training accuracy 0.96
# step 2137, training accuracy 0.96
# step 2138, training accuracy 0.96
# step 2139, training accuracy 0.96
# step 2140, training accuracy 0.96
# step 2141, training accuracy 0.96
# step 2142, training accuracy 0.96
# step 2143, training accuracy 0.96
# step 2144, training accuracy 0.96
# step 2145, training accuracy 0.96
# step 2146, training accuracy 0.96
# step 2147, training accuracy 0.96
# step 2148, training accuracy 0.96
# step 2149, training accuracy 0.96
# step 2150, training accuracy 0.96
# step 2151, training accuracy 0.96
# step 2152, training accuracy 0.96
# step 2153, training accuracy 0.96
# step 2154, training accuracy 0.96
# step 2155, training accuracy 0.96
# step 2156, training accuracy 0.96
# step 2157, training accuracy 0.96
# step 2158, training accuracy 0.96
# step 2159, training accuracy 0.96
# step 2160, training accuracy 0.96
# step 2161, training accuracy 0.96
# step 2162, training accuracy 0.96
# step 2163, training accuracy 0.96
# step 2164, training accuracy 0.96
# step 2165, training accuracy 0.96
# step 2166, training accuracy 0.96
# step 2167, training accuracy 0.96
# step 2168, training accuracy 0.96
# step 2169, training accuracy 0.96
# step 2170, training accuracy 0.96
# step 2171, training accuracy 0.96
# step 2172, training accuracy 0.96
# step 2173, training accuracy 0.96
# step 2174, training accuracy 0.96
# step 2175, training accuracy 0.96
# step 2176, training accuracy 0.96
# step 2177, training accuracy 0.96
# step 2178, training accuracy 0.96
# step 2179, training accuracy 0.96
# step 2180, training accuracy 0.96
# step 2181, training accuracy 0.96
# step 2182, training accuracy 0.96
# step 2183, training accuracy 0.96
# step 2184, training accuracy 0.96
# step 2185, training accuracy 0.96
# step 2186, training accuracy 0.96
# step 2187, training accuracy 0.96
# step 2188, training accuracy 0.96
# step 2189, training accuracy 0.96
# step 2190, training accuracy 0.96
# step 2191, training accuracy 0.96
# step 2192, training accuracy 0.96
# step 2193, training accuracy 0.96
# step 2194, training accuracy 0.96
# step 2195, training accuracy 0.96
# step 2196, training accuracy 0.96
# step 2197, training accuracy 0.96
# step 2198, training accuracy 0.96
# step 2199, training accuracy 0.96
# step 2200, training accuracy 0.96
# step 2201, training accuracy 0.96
# step 2202, training accuracy 0.96
# step 2203, training accuracy 0.96
# step 2204, training accuracy 0.96
# step 2205, training accuracy 0.96
# step 2206, training accuracy 0.96
# step 2207, training accuracy 0.96
# step 2208, training accuracy 0.96
# step 2209, training accuracy 0.96
# step 2210, training accuracy 0.96
# step 2211, training accuracy 0.96
# step 2212, training accuracy 0.96
# step 2213, training accuracy 0.96
# step 2214, training accuracy 0.96
# step 2215, training accuracy 0.96
# step 2216, training accuracy 0.96
# step 2217, training accuracy 0.96
# step 2218, training accuracy 0.96
# step 2219, training accuracy 0.96
# step 2220, training accuracy 0.96
# step 2221, training accuracy 0.96
# step 2222, training accuracy 0.96
# step 2223, training accuracy 0.96
# step 2224, training accuracy 0.96
# step 2225, training accuracy 0.96
# step 2226, training accuracy 0.96
# step 2227, training accuracy 0.96
# step 2228, training accuracy 0.96
# step 2229, training accuracy 0.96
# step 2230, training accuracy 0.96
# step 2231, training accuracy 0.96
# step 2232, training accuracy 0.96
# step 2233, training accuracy 0.96
# step 2234, training accuracy 0.96
# step 2235, training accuracy 0.96
# step 2236, training accuracy 0.96
# step 2237, training accuracy 0.96
# step 2238, training accuracy 0.96
# step 2239, training accuracy 0.96
# step 2240, training accuracy 0.96
# step 2241, training accuracy 0.96
# step 2242, training accuracy 0.96
# step 2243, training accuracy 0.96
# step 2244, training accuracy 0.96
# step 2245, training accuracy 0.96
# step 2246, training accuracy 0.96
# step 2247, training accuracy 0.96
# step 2248, training accuracy 0.96
# step 2249, training accuracy 0.96
# step 2250, training accuracy 0.96
# step 2251, training accuracy 0.96
# step 2252, training accuracy 0.96
# step 2253, training accuracy 0.96
# step 2254, training accuracy 0.96
# step 2255, training accuracy 0.96
# step 2256, training accuracy 0.96
# step 2257, training accuracy 0.96
# step 2258, training accuracy 0.96
# step 2259, training accuracy 0.96
# step 2260, training accuracy 0.96
# step 2261, training accuracy 0.96
# step 2262, training accuracy 0.96
# step 2263, training accuracy 0.96
# step 2264, training accuracy 0.96
# step 2265, training accuracy 0.96
# step 2266, training accuracy 0.96
# step 2267, training accuracy 0.96
# step 2268, training accuracy 0.96
# step 2269, training accuracy 0.96
# step 2270, training accuracy 0.96
# step 2271, training accuracy 0.96
# step 2272, training accuracy 0.96
# step 2273, training accuracy 0.96
# step 2274, training accuracy 0.96
# step 2275, training accuracy 0.96
# step 2276, training accuracy 0.96
# step 2277, training accuracy 0.96
# step 2278, training accuracy 0.96
# step 2279, training accuracy 0.96
# step 2280, training accuracy 0.96
# step 2281, training accuracy 0.96
# step 2282, training accuracy 0.96
# step 2283, training accuracy 0.96
# step 2284, training accuracy 0.96
# step 2285, training accuracy 0.96
# step 2286, training accuracy 0.96
# step 2287, training accuracy 0.96
# step 2288, training accuracy 0.96
# step 2289, training accuracy 0.96
# step 2290, training accuracy 0.96
# step 2291, training accuracy 0.96
# step 2292, training accuracy 0.96
# step 2293, training accuracy 0.96
# step 2294, training accuracy 0.96
# step 2295, training accuracy 0.96
# step 2296, training accuracy 0.96
# step 2297, training accuracy 0.96
# step 2298, training accuracy 0.96
# step 2299, training accuracy 0.96
# step 2300, training accuracy 1
# step 2301, training accuracy 1
# step 2302, training accuracy 1
# step 2303, training accuracy 1
# step 2304, training accuracy 1
# step 2305, training accuracy 1
# step 2306, training accuracy 1
# step 2307, training accuracy 1
# step 2308, training accuracy 1
# step 2309, training accuracy 1
# step 2310, training accuracy 1
# step 2311, training accuracy 1
# step 2312, training accuracy 1
# step 2313, training accuracy 1
# step 2314, training accuracy 1
# step 2315, training accuracy 1
# step 2316, training accuracy 1
# step 2317, training accuracy 1
# step 2318, training accuracy 1
# step 2319, training accuracy 1
# step 2320, training accuracy 1
# step 2321, training accuracy 1
# step 2322, training accuracy 1
# step 2323, training accuracy 1
# step 2324, training accuracy 1
# step 2325, training accuracy 1
# step 2326, training accuracy 1
# step 2327, training accuracy 1
# step 2328, training accuracy 1
# step 2329, training accuracy 1
# step 2330, training accuracy 1
# step 2331, training accuracy 1
# step 2332, training accuracy 1
# step 2333, training accuracy 1
# step 2334, training accuracy 1
# step 2335, training accuracy 1
# step 2336, training accuracy 1
# step 2337, training accuracy 1
# step 2338, training accuracy 1
# step 2339, training accuracy 1
# step 2340, training accuracy 1
# step 2341, training accuracy 1
# step 2342, training accuracy 1
# step 2343, training accuracy 1
# step 2344, training accuracy 1
# step 2345, training accuracy 1
# step 2346, training accuracy 1
# step 2347, training accuracy 1
# step 2348, training accuracy 1
# step 2349, training accuracy 1
# step 2350, training accuracy 1
# step 2351, training accuracy 1
# step 2352, training accuracy 1
# step 2353, training accuracy 1
# step 2354, training accuracy 1
# step 2355, training accuracy 1
# step 2356, training accuracy 1
# step 2357, training accuracy 1
# step 2358, training accuracy 1
# step 2359, training accuracy 1
# step 2360, training accuracy 1
# step 2361, training accuracy 1
# step 2362, training accuracy 1
# step 2363, training accuracy 1
# step 2364, training accuracy 1
# step 2365, training accuracy 1
# step 2366, training accuracy 1
# step 2367, training accuracy 1
# step 2368, training accuracy 1
# step 2369, training accuracy 1
# step 2370, training accuracy 1
# step 2371, training accuracy 1
# step 2372, training accuracy 1
# step 2373, training accuracy 1
# step 2374, training accuracy 1
# step 2375, training accuracy 1
# step 2376, training accuracy 1
# step 2377, training accuracy 1
# step 2378, training accuracy 1
# step 2379, training accuracy 1
# step 2380, training accuracy 1
# step 2381, training accuracy 1
# step 2382, training accuracy 1
# step 2383, training accuracy 1
# step 2384, training accuracy 1
# step 2385, training accuracy 1
# step 2386, training accuracy 1
# step 2387, training accuracy 1
# step 2388, training accuracy 1
# step 2389, training accuracy 1
# step 2390, training accuracy 1
# step 2391, training accuracy 1
# step 2392, training accuracy 1
# step 2393, training accuracy 1
# step 2394, training accuracy 1
# step 2395, training accuracy 1
# step 2396, training accuracy 1
# step 2397, training accuracy 1
# step 2398, training accuracy 1
# step 2399, training accuracy 1
# step 2400, training accuracy 0.98
# step 2401, training accuracy 0.98
# step 2402, training accuracy 0.98
# step 2403, training accuracy 0.98
# step 2404, training accuracy 0.98
# step 2405, training accuracy 0.98
# step 2406, training accuracy 0.98
# step 2407, training accuracy 0.98
# step 2408, training accuracy 0.98
# step 2409, training accuracy 0.98
# step 2410, training accuracy 0.98
# step 2411, training accuracy 0.98
# step 2412, training accuracy 0.98
# step 2413, training accuracy 0.98
# step 2414, training accuracy 0.98
